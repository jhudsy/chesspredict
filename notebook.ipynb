# %%
import keras

from keras.layers import Dense
from keras.layers import LSTM
from keras.layers import Input
#from keras.layers import CategoryEncoding
import keras_tuner as kt


import os

import tensorflow as tf

import chess
import chess.pgn


import numpy as np

NUM_MOVES = 40 #number of moves to store in tensor

# %%
def get_ratings(game):

    return int(game.headers['WhiteElo']),int(game.headers['BlackElo'])

def rating_to_output(rating):
    ret = np.zeros(48)
    r = int((rating-600)/50)
    if r>47:
        r = 47
    if r<0:
        r = 0
    ret[r] = 1
    return ret

def get_game_tensors(game_pgn,num_tensors):

    gt = np.zeros((num_tensors,134))

    moves = []
    evals = []

    for m in game_pgn.mainline():
        moves.append(m.san())
        if m.eval() is None: #should only happen on a mate
            evals.append(None)
        else:
            evals.append(m.eval().white() if m.turn() == chess.WHITE else m.eval().black())

    #let our t vector be a 1D array of 133 elements. The first 128 element represent the board before the move is made and after the move is made. The 129th element is the evaluation of the move before it is made and the 130th element is the evaluation of the move after it is made. If it is mate in X moves before the move is made, the 131st element is 1 and 0 otherwise. If it is mate in X moves after the move is made, the 132nd element is 1 and 0 otherwise. The 133rd element is 1 if it is white moved and -1 if it is black making the move.

    board = chess.Board()

    for m in range(0,min(num_tensors,len(moves)-1)):
        t = np.zeros(134)

        for i in range(64): #original board position
            if board.piece_at(i) is not None:
                                t[i] = board.piece_at(i).piece_type * (1 if board.piece_at(i).color == chess.WHITE else -1)

        board.push_san(moves[m])
        for i in range(64):
            if board.piece_at(i) is not None:
                t[i+64] = board.piece_at(i).piece_type * (1 if board.piece_at(i).color == chess.WHITE else -1)

        #evals is either a number, or starts with a #. If it starts with a #, it is a mate in X moves

        #handle the case of a mate
        if evals[m] is None:
            t[129] = 0
            t[130] = 1
        if evals[m+1] is None:
            t[131] = 0
            t[132] = 1

        if evals[m] is not None and evals[m].is_mate():
            t[129] = float(evals[m].mate())
            t[130] = 1
        elif evals[m] is not None:
            t[129] = float(evals[m].score()/100)
            t[130] = 0

        if evals[m+1] is not None and evals[m+1].is_mate():
            t[131] = float(evals[m+1].mate())
            t[132] = 1
        elif evals[m+1] is not None:
            t[131] = float(evals[m+1].score()/100)
            t[132] = 0

        t[133] = -1 if board.turn == chess.WHITE else 1

        gt[m] = t

    return gt

# %%
def make_data(path,target_file):
    count = 0
    files = [f for f in os.listdir(path) if os.path.isfile(os.path.join(path, f))]

    X,y1,y2 = [],[],[]
    for f in files:
        count += 1
        if count % 10000 == 0:
            print("Processed " + str(count) + " files out of " + str(len(files)))
        
        with open(os.path.join(path,f)) as pgn:
            game = chess.pgn.read_game(pgn)
            gt = get_game_tensors(game,NUM_MOVES)
            y1t = get_ratings(game)[0]
            y2t = get_ratings(game)[1]

            X.append(gt)
            y1.append(y1t)
            y2.append(y2t)

        #delete the file
        #os.remove(os.path.join(path,f))

    X = np.array(X)
    y1 = np.array(y1)
    y2 = np.array(y2)

    #save the data to the target file
    np.savez_compressed(os.path.join(path,target_file + "_X.npz"),X)
    np.savez_compressed(os.path.join(path,target_file + "_y1.npz"),y1)
    np.savez_compressed(os.path.join(path,target_file + "_y2.npz"),y2)

def load_data(path,target_file):
    X = np.load(os.path.join(path,target_file + "_X.npz"))
    y1 = np.load(os.path.join(path,target_file + "_y1.npz"))
    y2 = np.load(os.path.join(path,target_file + "_y2.npz"))

    return X,y1,y2

#if the data doesn't exist, generate it
if not os.path.exists("data/all_data/data_X.npz"):
    make_data("data/all_data","data")
X,y1,y2 = load_data("data/all_data","data")

# %%
def model_builder(hp):

    lstm1_units = hp.Int('lstm1_units',min_value=32,max_value=512,step=32)
    lstm2_units = hp.Int('lstm2_units',min_value=32,max_value=256,step=32)
    dense1_units = hp.Int('dense1_units',min_value=32,max_value=256,step=32)
    dense2_units = hp.Int('dense2_units',min_value=32,max_value=256,step=32)
    input = Input(shape=(NUM_MOVES, 134))
    x = LSTM(lstm1_units,return_sequences=True)(input)
    x = LSTM(lstm2_units)(x)
    x = Dense(dense1_units,activation='relu')(x)
    x = Dense(dense2_units,activation='relu')(x)

    output1 = Dense(1,activation='relu',name="WhiteElo")(x)
    output2 = Dense(1,activation='relu',name="BlackElo")(x)

    hp_learning_rate = hp.Choice('learning_rate', values=[1e-2, 1e-3, 1e-4])

    model = keras.Model(inputs=input,outputs=[output1,output2])

    model.compile(optimizer=keras.optimizers.Adam(learning_rate=hp_learning_rate),
                    loss={'WhiteElo':'mse','BlackElo':'mse'},
                    metrics={'WhiteElo':'mae','BlackElo':'mae'})

    return model

# %%
tuner = kt.Hyperband(model_builder,
                     objective='val_loss',
                    max_epochs=100,
                    factor=3)

stop_early = tf.keras.callbacks.EarlyStopping(monitor='val_loss', patience=5)
save = tf.keras.callbacks.ModelCheckpoint('model.keras', save_best_only=True,mode='auto',monitor='val_loss')

tuner.search(X,(y1,y2),epochs=100,validation_split=0.2,callbacks=[stop_early])

best_hps = tuner.get_best_hyperparameters(num_trials=1)[0]

print(best_hps.values)

model = tuner.hypermodel.build(best_hps)

history = model.fit(X,(y1,y2),epochs=100,validation_split=0.2,callbacks=[stop_early,save])
model.save('model3.keras')
# Out:
# Trial 75 Complete [00h 00m 04s]
# val_loss: 4912320.5
#
# Best val_loss So Far: 205703.4375
# Total elapsed time: 00h 04m 59s
#
# Search: Running Trial #76
#
# Value             |Best Value So Far |Hyperparameter
# 416               |128               |lstm1_units
# 128               |32                |lstm2_units
# 224               |160               |dense1_units
# 160               |256               |dense2_units
# 0.0001            |0.01              |learning_rate
# 2                 |2                 |tuner/epochs
# 0                 |0                 |tuner/initial_epoch
# 4                 |4                 |tuner/bracket
# 0                 |0                 |tuner/round
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[6], line 9
#       6 stop_early = tf.keras.callbacks.EarlyStopping(monitor='val_loss', patience=5)
#       7 save = tf.keras.callbacks.ModelCheckpoint('model.keras', save_best_only=True,mode='auto',monitor='val_loss')
# ----> 9 tuner.search(X,(y1,y2),epochs=100,validation_split=0.2,callbacks=[stop_early])
#      11 best_hps = tuner.get_best_hyperparameters(num_trials=1)[0]
#      13 print(best_hps.values)
#
# File ~/scratch/chesspredict/.venv/lib/python3.10/site-packages/keras_tuner/src/engine/base_tuner.py:234, in BaseTuner.search(self, *fit_args, **fit_kwargs)
#     231         continue
#     233     self.on_trial_begin(trial)
# --> 234     self._try_run_and_update_trial(trial, *fit_args, **fit_kwargs)
#     235     self.on_trial_end(trial)
#     236 self.on_search_end()
#
# File ~/scratch/chesspredict/.venv/lib/python3.10/site-packages/keras_tuner/src/engine/base_tuner.py:274, in BaseTuner._try_run_and_update_trial(self, trial, *fit_args, **fit_kwargs)
#     272 def _try_run_and_update_trial(self, trial, *fit_args, **fit_kwargs):
#     273     try:
# --> 274         self._run_and_update_trial(trial, *fit_args, **fit_kwargs)
#     275         trial.status = trial_module.TrialStatus.COMPLETED
#     276         return
#
# File ~/scratch/chesspredict/.venv/lib/python3.10/site-packages/keras_tuner/src/engine/base_tuner.py:239, in BaseTuner._run_and_update_trial(self, trial, *fit_args, **fit_kwargs)
#     238 def _run_and_update_trial(self, trial, *fit_args, **fit_kwargs):
# --> 239     results = self.run_trial(trial, *fit_args, **fit_kwargs)
#     240     if self.oracle.get_trial(trial.trial_id).metrics.exists(
#     241         self.oracle.objective.name
#     242     ):
#     243         # The oracle is updated by calling `self.oracle.update_trial()` in
#     244         # `Tuner.run_trial()`. For backward compatibility, we support this
#     245         # use case. No further action needed in this case.
#     246         warnings.warn(
#     247             "The use case of calling "
#     248             "`self.oracle.update_trial(trial_id, metrics)` "
#    (...)
#     254             stacklevel=2,
#     255         )
#
# File ~/scratch/chesspredict/.venv/lib/python3.10/site-packages/keras_tuner/src/tuners/hyperband.py:427, in Hyperband.run_trial(self, trial, *fit_args, **fit_kwargs)
#     425     fit_kwargs["epochs"] = hp.values["tuner/epochs"]
#     426     fit_kwargs["initial_epoch"] = hp.values["tuner/initial_epoch"]
# --> 427 return super().run_trial(trial, *fit_args, **fit_kwargs)
#
# File ~/scratch/chesspredict/.venv/lib/python3.10/site-packages/keras_tuner/src/engine/tuner.py:314, in Tuner.run_trial(self, trial, *args, **kwargs)
#     312     callbacks.append(model_checkpoint)
#     313     copied_kwargs["callbacks"] = callbacks
# --> 314     obj_value = self._build_and_fit_model(trial, *args, **copied_kwargs)
#     316     histories.append(obj_value)
#     317 return histories
#
# File ~/scratch/chesspredict/.venv/lib/python3.10/site-packages/keras_tuner/src/engine/tuner.py:232, in Tuner._build_and_fit_model(self, trial, *args, **kwargs)
#     214 """For AutoKeras to override.
#     215
#     216 DO NOT REMOVE this function. AutoKeras overrides the function to tune
#    (...)
#     229     The fit history.
#     230 """
#     231 hp = trial.hyperparameters
# --> 232 model = self._try_build(hp)
#     233 results = self.hypermodel.fit(hp, model, *args, **kwargs)
#     235 # Save the build config for model loading later.
#
# File ~/scratch/chesspredict/.venv/lib/python3.10/site-packages/keras_tuner/src/engine/tuner.py:164, in Tuner._try_build(self, hp)
#     161 keras.backend.clear_session()
#     162 gc.collect()
# --> 164 model = self._build_hypermodel(hp)
#     165 # Stop if `build()` does not return a valid model.
#     166 if not isinstance(model, keras.models.Model):
#
# File ~/scratch/chesspredict/.venv/lib/python3.10/site-packages/keras_tuner/src/tuners/hyperband.py:430, in Hyperband._build_hypermodel(self, hp)
#     429 def _build_hypermodel(self, hp):
# --> 430     model = super()._build_hypermodel(hp)
#     431     if "tuner/trial_id" in hp.values:
#     432         trial_id = hp.values["tuner/trial_id"]
#
# File ~/scratch/chesspredict/.venv/lib/python3.10/site-packages/keras_tuner/src/engine/tuner.py:155, in Tuner._build_hypermodel(self, hp)
#     153 def _build_hypermodel(self, hp):
#     154     with maybe_distribute(self.distribution_strategy):
# --> 155         model = self.hypermodel.build(hp)
#     156         self._override_compile_args(model)
#     157         return model
#
# Cell In[5], line 8, in model_builder(hp)
#       6 dense2_units = hp.Int('dense2_units',min_value=32,max_value=256,step=32)
#       7 input = Input(shape=(NUM_MOVES, 134))
# ----> 8 x = LSTM(lstm1_units,return_sequences=True)(input)
#       9 x = LSTM(lstm2_units)(x)
#      10 x = Dense(dense1_units,activation='relu')(x)
#
# File ~/scratch/chesspredict/.venv/lib/python3.10/site-packages/keras/src/utils/traceback_utils.py:117, in filter_traceback.<locals>.error_handler(*args, **kwargs)
#     115 filtered_tb = None
#     116 try:
# --> 117     return fn(*args, **kwargs)
#     118 except Exception as e:
#     119     filtered_tb = _process_traceback_frames(e.__traceback__)
#
# File ~/scratch/chesspredict/.venv/lib/python3.10/site-packages/keras/src/layers/layer.py:826, in Layer.__call__(self, *args, **kwargs)
#     823 ################
#     824 # 4. Call build
#     825 with self._open_name_scope():
# --> 826     self._maybe_build(call_spec)
#     828 ##########################
#     829 # 5. Infer training value
#     830 # Training phase for `Layer.call` is set via (in order of priority):
#    (...)
#     836 # Maintains info about the `Layer.call` stack
#     837 # across nested calls.
#     838 call_context = self._get_call_context()
#
# File ~/scratch/chesspredict/.venv/lib/python3.10/site-packages/keras/src/layers/layer.py:1365, in Layer._maybe_build(self, call_spec)
#    1358 if not utils.is_default(self.build):
#    1359     shapes_dict = update_shapes_dict_for_target_fn(
#    1360         self.build,
#    1361         shapes_dict=shapes_dict,
#    1362         call_spec=call_spec,
#    1363         class_name=self.__class__.__name__,
#    1364     )
# -> 1365     self.build(**shapes_dict)
#    1366     # Check input spec again (after build, since self.input_spec
#    1367     # may have been updated
#    1368     self._assert_input_compatibility(call_spec.first_arg)
#
# File ~/scratch/chesspredict/.venv/lib/python3.10/site-packages/keras/src/layers/layer.py:226, in Layer.__new__.<locals>.build_wrapper(*args, **kwargs)
#     224 with obj._open_name_scope():
#     225     obj._path = current_path()
# --> 226     original_build_method(*args, **kwargs)
#     227 # Record build config.
#     228 signature = inspect.signature(original_build_method)
#
# File ~/scratch/chesspredict/.venv/lib/python3.10/site-packages/keras/src/layers/rnn/rnn.py:274, in RNN.build(self, sequences_shape, initial_state_shape)
#     272 step_input_shape = (sequences_shape[0],) + tuple(sequences_shape[2:])
#     273 if isinstance(self.cell, Layer) and not self.cell.built:
# --> 274     self.cell.build(step_input_shape)
#     275     self.cell.built = True
#     276 if self.stateful:
#
# File ~/scratch/chesspredict/.venv/lib/python3.10/site-packages/keras/src/layers/layer.py:226, in Layer.__new__.<locals>.build_wrapper(*args, **kwargs)
#     224 with obj._open_name_scope():
#     225     obj._path = current_path()
# --> 226     original_build_method(*args, **kwargs)
#     227 # Record build config.
#     228 signature = inspect.signature(original_build_method)
#
# File ~/scratch/chesspredict/.venv/lib/python3.10/site-packages/keras/src/layers/rnn/lstm.py:153, in LSTMCell.build(self, input_shape)
#     145 input_dim = input_shape[-1]
#     146 self.kernel = self.add_weight(
#     147     shape=(input_dim, self.units * 4),
#     148     name="kernel",
#    (...)
#     151     constraint=self.kernel_constraint,
#     152 )
# --> 153 self.recurrent_kernel = self.add_weight(
#     154     shape=(self.units, self.units * 4),
#     155     name="recurrent_kernel",
#     156     initializer=self.recurrent_initializer,
#     157     regularizer=self.recurrent_regularizer,
#     158     constraint=self.recurrent_constraint,
#     159 )
#     161 if self.use_bias:
#     162     if self.unit_forget_bias:
#
# File ~/scratch/chesspredict/.venv/lib/python3.10/site-packages/keras/src/layers/layer.py:541, in Layer.add_weight(self, shape, initializer, dtype, trainable, autocast, regularizer, constraint, aggregation, name)
#     539 initializer = initializers.get(initializer)
#     540 with backend.name_scope(self.name, caller=self):
# --> 541     variable = backend.Variable(
#     542         initializer=initializer,
#     543         shape=shape,
#     544         dtype=dtype,
#     545         trainable=trainable,
#     546         autocast=autocast,
#     547         aggregation=aggregation,
#     548         name=name,
#     549     )
#     550 # Will be added to layer.losses
#     551 variable.regularizer = regularizers.get(regularizer)
#
# File ~/scratch/chesspredict/.venv/lib/python3.10/site-packages/keras/src/backend/common/variables.py:170, in Variable.__init__(self, initializer, shape, dtype, trainable, autocast, aggregation, name)
#     168 if callable(initializer):
#     169     self._shape = self._validate_shape(shape)
# --> 170     self._initialize_with_initializer(initializer)
#     171 else:
#     172     self._initialize(initializer)
#
# File ~/scratch/chesspredict/.venv/lib/python3.10/site-packages/keras/src/backend/tensorflow/core.py:47, in Variable._initialize_with_initializer(self, initializer)
#      46 def _initialize_with_initializer(self, initializer):
# ---> 47     self._value = tf.Variable(
#      48         lambda: initializer(self._shape, dtype=self._dtype),
#      49         dtype=self._dtype,
#      50         trainable=self.trainable,
#      51         name=self.name,
#      52         aggregation=self._map_aggregation(self.aggregation),
#      53     )
#
# File ~/scratch/chesspredict/.venv/lib/python3.10/site-packages/tensorflow/python/util/traceback_utils.py:150, in filter_traceback.<locals>.error_handler(*args, **kwargs)
#     148 filtered_tb = None
#     149 try:
# --> 150   return fn(*args, **kwargs)
#     151 except Exception as e:
#     152   filtered_tb = _process_traceback_frames(e.__traceback__)
#
# File ~/scratch/chesspredict/.venv/lib/python3.10/site-packages/tensorflow/python/ops/variables.py:197, in VariableMetaclass.__call__(cls, *args, **kwargs)
#     194 @traceback_utils.filter_traceback
#     195 def __call__(cls, *args, **kwargs):
#     196   if hasattr(cls, "_variable_call") and callable(cls._variable_call):
# --> 197     variable_call = cls._variable_call(*args, **kwargs)
#     198     if variable_call is not None:
#     199       return variable_call
#
# File ~/scratch/chesspredict/.venv/lib/python3.10/site-packages/tensorflow/python/ops/variables.py:1229, in Variable._variable_call(cls, initial_value, trainable, validate_shape, caching_device, name, variable_def, dtype, import_scope, constraint, synchronization, aggregation, shape, experimental_enable_variable_lifting, **kwargs)
#    1227 if aggregation is None:
#    1228   aggregation = VariableAggregation.NONE
# -> 1229 return previous_getter(
#    1230     initial_value=initial_value,
#    1231     trainable=trainable,
#    1232     validate_shape=validate_shape,
#    1233     caching_device=caching_device,
#    1234     name=name,
#    1235     variable_def=variable_def,
#    1236     dtype=dtype,
#    1237     import_scope=import_scope,
#    1238     constraint=constraint,
#    1239     synchronization=synchronization,
#    1240     aggregation=aggregation,
#    1241     shape=shape,
#    1242     experimental_enable_variable_lifting=experimental_enable_variable_lifting,
#    1243     **kwargs
#    1244 )
#
# File ~/scratch/chesspredict/.venv/lib/python3.10/site-packages/tensorflow/python/ops/variables.py:1222, in Variable._variable_call.<locals>.<lambda>(**kws)
#    1220 if cls is not Variable:
#    1221   return None
# -> 1222 previous_getter = lambda **kws: default_variable_creator_v2(None, **kws)
#    1223 for _, getter in ops.get_default_graph()._variable_creator_stack:  # pylint: disable=protected-access
#    1224   previous_getter = _make_getter(getter, previous_getter)
#
# File ~/scratch/chesspredict/.venv/lib/python3.10/site-packages/tensorflow/python/ops/variables.py:50, in default_variable_creator_v2(next_creator, **kwds)
#      47 def default_variable_creator_v2(next_creator=None, **kwds):
#      48   from tensorflow.python.ops import resource_variable_ops  # pylint: disable=g-import-not-at-top
# ---> 50   return resource_variable_ops.default_variable_creator_v2(
#      51       next_creator=next_creator, **kwds)
#
# File ~/scratch/chesspredict/.venv/lib/python3.10/site-packages/tensorflow/python/ops/resource_variable_ops.py:355, in default_variable_creator_v2(next_creator, **kwargs)
#     351 shape = kwargs.get("shape", None)
#     352 experimental_enable_variable_lifting = kwargs.get(
#     353     "experimental_enable_variable_lifting", None)
# --> 355 return ResourceVariable(
#     356     initial_value=initial_value,
#     357     trainable=trainable,
#     358     validate_shape=validate_shape,
#     359     caching_device=caching_device,
#     360     name=name,
#     361     dtype=dtype,
#     362     constraint=constraint,
#     363     variable_def=variable_def,
#     364     import_scope=import_scope,
#     365     distribute_strategy=distribute_strategy,
#     366     synchronization=synchronization,
#     367     aggregation=aggregation,
#     368     shape=shape,
#     369     experimental_enable_variable_lifting=experimental_enable_variable_lifting,
#     370     )
#
# File ~/scratch/chesspredict/.venv/lib/python3.10/site-packages/tensorflow/python/util/traceback_utils.py:150, in filter_traceback.<locals>.error_handler(*args, **kwargs)
#     148 filtered_tb = None
#     149 try:
# --> 150   return fn(*args, **kwargs)
#     151 except Exception as e:
#     152   filtered_tb = _process_traceback_frames(e.__traceback__)
#
# File ~/scratch/chesspredict/.venv/lib/python3.10/site-packages/tensorflow/python/ops/variables.py:200, in VariableMetaclass.__call__(cls, *args, **kwargs)
#     198   if variable_call is not None:
#     199     return variable_call
# --> 200 return super(VariableMetaclass, cls).__call__(*args, **kwargs)
#
# File ~/scratch/chesspredict/.venv/lib/python3.10/site-packages/tensorflow/python/ops/resource_variable_ops.py:1829, in ResourceVariable.__init__(self, initial_value, trainable, collections, validate_shape, caching_device, name, dtype, variable_def, import_scope, constraint, distribute_strategy, synchronization, aggregation, shape, handle, experimental_enable_variable_lifting)
#    1824   self._init_from_handle(trainable=trainable,
#    1825                          shape=shape,
#    1826                          dtype=dtype,
#    1827                          handle=handle)
#    1828 else:
# -> 1829   self._init_from_args(
#    1830       initial_value=initial_value,
#    1831       trainable=trainable,
#    1832       collections=collections,
#    1833       caching_device=caching_device,
#    1834       name=name,
#    1835       dtype=dtype,
#    1836       constraint=constraint,
#    1837       synchronization=synchronization,
#    1838       aggregation=aggregation,
#    1839       shape=shape,
#    1840       distribute_strategy=distribute_strategy,
#    1841       validate_shape=validate_shape,
#    1842       experimental_enable_variable_lifting=experimental_enable_variable_lifting,
#    1843       )
#
# File ~/scratch/chesspredict/.venv/lib/python3.10/site-packages/tensorflow/python/ops/resource_variable_ops.py:2013, in ResourceVariable._init_from_args(self, initial_value, trainable, collections, caching_device, name, dtype, constraint, synchronization, aggregation, distribute_strategy, shape, validate_shape, experimental_enable_variable_lifting)
#    2011 with ops.name_scope("Initializer"), device_context_manager(None):
#    2012   if init_from_fn:
# -> 2013     initial_value = initial_value()
#    2014   if isinstance(initial_value, trackable.CheckpointInitialValue):
#    2015     self._maybe_initialize_trackable()
#
# File ~/scratch/chesspredict/.venv/lib/python3.10/site-packages/keras/src/backend/tensorflow/core.py:48, in Variable._initialize_with_initializer.<locals>.<lambda>()
#      46 def _initialize_with_initializer(self, initializer):
#      47     self._value = tf.Variable(
# ---> 48         lambda: initializer(self._shape, dtype=self._dtype),
#      49         dtype=self._dtype,
#      50         trainable=self.trainable,
#      51         name=self.name,
#      52         aggregation=self._map_aggregation(self.aggregation),
#      53     )
#
# File ~/scratch/chesspredict/.venv/lib/python3.10/site-packages/keras/src/initializers/random_initializers.py:702, in Orthogonal.__call__(self, shape, dtype)
#     699 flat_shape = (max(num_cols, num_rows), min(num_cols, num_rows))
#     701 # Generate a random matrix
# --> 702 a = random.normal(flat_shape, seed=self.seed, dtype=dtype)
#     703 # Compute the qr factorization
#     704 q, r = ops.qr(a)
#
# File ~/scratch/chesspredict/.venv/lib/python3.10/site-packages/keras/src/backend/tensorflow/random.py:26, in normal(shape, mean, stddev, dtype, seed)
#      24 dtype = dtype or floatx()
#      25 seed = _cast_seed(draw_seed(seed))
# ---> 26 return tf.random.stateless_normal(
#      27     shape=shape, mean=mean, stddev=stddev, dtype=dtype, seed=seed
#      28 )
#
# File ~/scratch/chesspredict/.venv/lib/python3.10/site-packages/tensorflow/python/util/traceback_utils.py:150, in filter_traceback.<locals>.error_handler(*args, **kwargs)
#     148 filtered_tb = None
#     149 try:
# --> 150   return fn(*args, **kwargs)
#     151 except Exception as e:
#     152   filtered_tb = _process_traceback_frames(e.__traceback__)
#
# File ~/scratch/chesspredict/.venv/lib/python3.10/site-packages/tensorflow/python/util/dispatch.py:1260, in add_dispatch_support.<locals>.decorator.<locals>.op_dispatch_handler(*args, **kwargs)
#    1258 # Fallback dispatch system (dispatch v1):
#    1259 try:
# -> 1260   return dispatch_target(*args, **kwargs)
#    1261 except (TypeError, ValueError):
#    1262   # Note: convert_to_eager_tensor currently raises a ValueError, not a
#    1263   # TypeError, when given unexpected types.  So we need to catch both.
#    1264   result = dispatch(op_dispatch_handler, args, kwargs)
#
# File ~/scratch/chesspredict/.venv/lib/python3.10/site-packages/tensorflow/python/ops/stateless_random_ops.py:687, in stateless_random_normal(shape, seed, mean, stddev, dtype, name, alg)
#     685 stddev = ops.convert_to_tensor(stddev, dtype=dtype, name="stddev")
#     686 key, counter, alg = random_ops_util.get_key_counter_alg(seed, alg)
# --> 687 rnd = gen_stateless_random_ops_v2.stateless_random_normal_v2(
#     688     shape, key=key, counter=counter, dtype=dtype, alg=alg
#     689 )
#     690 result = math_ops.add(rnd * stddev, mean, name=name)
#     691 shape_util.maybe_set_static_shape(result, shape)
#
# File ~/scratch/chesspredict/.venv/lib/python3.10/site-packages/tensorflow/python/ops/gen_stateless_random_ops_v2.py:331, in stateless_random_normal_v2(shape, key, counter, alg, dtype, name)
#     329   pass
#     330 try:
# --> 331   return stateless_random_normal_v2_eager_fallback(
#     332       shape, key, counter, alg, dtype=dtype, name=name, ctx=_ctx)
#     333 except _core._SymbolicException:
#     334   pass  # Add nodes to the TensorFlow graph.
#
# File ~/scratch/chesspredict/.venv/lib/python3.10/site-packages/tensorflow/python/ops/gen_stateless_random_ops_v2.py:365, in stateless_random_normal_v2_eager_fallback(shape, key, counter, alg, dtype, name, ctx)
#     363 _inputs_flat = [shape, key, counter, alg]
#     364 _attrs = ("dtype", dtype, "Tshape", _attr_Tshape)
# --> 365 _result = _execute.execute(b"StatelessRandomNormalV2", 1,
#     366                            inputs=_inputs_flat, attrs=_attrs, ctx=ctx,
#     367                            name=name)
#     368 if _execute.must_record_gradient():
#     369   _execute.record_gradient(
#     370       "StatelessRandomNormalV2", _inputs_flat, _attrs, _result)
#
# File ~/scratch/chesspredict/.venv/lib/python3.10/site-packages/tensorflow/python/eager/execute.py:53, in quick_execute(op_name, num_outputs, inputs, attrs, ctx, name)
#      51 try:
#      52   ctx.ensure_initialized()
# ---> 53   tensors = pywrap_tfe.TFE_Py_Execute(ctx._handle, device_name, op_name,
#      54                                       inputs, attrs, num_outputs)
#      55 except core._NotOkStatusException as e:
#      56   if name is not None:
#
# KeyboardInterrupt:
